# %%
import matplotlib.pyplot as plt
import pickle as pkl

# %%
RESULT_PATH: str = "/scratch/ssnyde9/boroa/ann/closed_roa/grid_search_12/avg_config_losses.pkl"

# %%
losses = pkl.load(open(RESULT_PATH, "rb"))
print(len(losses))
# Out:
# 55

# %%
plt.plot(sorted(losses), "bo-")
plt.xlabel('Configuration')
plt.ylabel('Average Loss')
plt.title('Average Losses / Configuration')
# Out:
# Text(0.5, 1.0, 'Average Losses / Configuration')
