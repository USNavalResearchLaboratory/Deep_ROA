# %%
import matplotlib.pyplot as plt
import pickle as pkl
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
RESULT_PATH_0: str = "/Users/shaysnyder/Desktop/boroa-results/grid_search_13_1/avg_config_losses.pkl"
RESULT_PATH_1: str = "/Users/shaysnyder/Desktop/boroa-results/grid_search_13_2/avg_config_losses.pkl"
RESULT_PATH_2: str = "/Users/shaysnyder/Desktop/boroa-results/grid_search_13_3/avg_config_losses.pkl"
RESULT_PATH_3: str = "/Users/shaysnyder/Desktop/boroa-results/grid_search_13_4/avg_config_losses.pkl"
RESULT_PATH_4: str = "/Users/shaysnyder/Desktop/boroa-results/grid_search_13_5/avg_config_losses.pkl"
RESULT_PATH_5: str = "/Users/shaysnyder/Desktop/boroa-results/grid_search_13_6/avg_config_losses.pkl"
RESULT_PATH_6: str = "/Users/shaysnyder/Desktop/boroa-results/grid_search_13_7/avg_config_losses.pkl"
RESULT_PATH_7: str = "/Users/shaysnyder/Desktop/boroa-results/grid_search_13_8/avg_config_losses.pkl"

# %%
losses_0 = pkl.load(open(RESULT_PATH_0, "rb"))
losses_1 = pkl.load(open(RESULT_PATH_1, "rb"))
losses_2 = pkl.load(open(RESULT_PATH_2, "rb"))
losses_3 = pkl.load(open(RESULT_PATH_3, "rb"))
losses_4 = pkl.load(open(RESULT_PATH_4, "rb"))
losses_5 = pkl.load(open(RESULT_PATH_5, "rb"))
losses_6 = pkl.load(open(RESULT_PATH_6, "rb"))
losses_7 = pkl.load(open(RESULT_PATH_7, "rb"))


losses = []
losses.extend(losses_0)
losses.extend(losses_1)
losses.extend(losses_2)
losses.extend(losses_3)
losses.extend(losses_4)
losses.extend(losses_5)
losses.extend(losses_6)
losses.extend(losses_7)

# %%
plt.plot(sorted(losses), "bo-")
plt.xlabel('Configuration')
plt.ylabel('Average Loss')
plt.title('Average Losses / Configuration')
# Out:
# Text(0.5, 1.0, 'Average Losses / Configuration')
